# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargav-inthezone/Ineuron_assignments/blob/main/sem_seg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !python /content/drive/MyDrive/pointnet/sem_seg/train.py --log_dir log6 --test_area 6
# Out:
# Streaming output truncated to the last 5000 lines.
# conv2/bn/batchnorm/mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-24 13:57:28.309583: I tensorflow/core/common_runtime/placer.cc:54] conv2/bn/batchnorm/mul_1: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# conv2/bn/batchnorm/mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-24 13:57:28.309600: I tensorflow/core/common_runtime/placer.cc:54] conv2/bn/batchnorm/mul_2: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# conv2/bn/batchnorm/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-24 13:57:28.309622: I tensorflow/core/common_runtime/placer.cc:54] conv2/bn/batchnorm/sub: (Sub): /job:localhost/replica:0/task:0/device:GPU:0
# conv2/bn/batchnorm/add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-24 13:57:28.309641: I tensorflow/core/common_runtime/placer.cc:54] conv2/bn/batchnorm/add_1: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# ...

# %%
! git clone https://github.com/charlesq34/pointnet.git
# Out:
# Cloning into 'pointnet'...
# remote: Enumerating objects: 232, done.
# remote: Total 232 (delta 0), reused 0 (delta 0), pack-reused 232
# Receiving objects: 100% (232/232), 529.15 KiB | 1.69 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
# !unzip "/content/drive/MyDrive/Stanford3dDataset_v1.2_Aligned_Version.zip" -d "/content/pointnet/data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/WC_1/Annotations/wall_5.txt
#   inflating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/WC_1/WC_1.txt
#    creating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/
#   inflating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/.DS_Store
#    creating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/
#   inflating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/floor_1.txt
#   inflating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/wall_2.txt
#   inflating: /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_2/hallway_9/Annotations/ceiling_1.txt
# ...

# %%
# !python /content/pointnet/sem_seg/collect_indoor3d_data.py
# Out:
# /content/pointnet/sem_seg
# /content/pointnet
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_1/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/conferenceRoom_2/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/copyRoom_1/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_1/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_2/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_3/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_4/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_5/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_6/Annotations
# /content/pointnet/data/Stanford3dDataset_v1.2_Aligned_Version/Area_1/hallway_7/Annotations
# ...

# %%
cd /content/pointnet/
# Out:
# /content/pointnet

# %%
# !python /content/pointnet/sem_seg/train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# conv5/bn/cond_1/switch_t: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-06-24 17:11:21.639816: I tensorflow/core/common_runtime/placer.cc:54] conv5/bn/cond_1/switch_t: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# conv5/bn/cond_1/switch_f: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-06-24 17:11:21.639837: I tensorflow/core/common_runtime/placer.cc:54] conv5/bn/cond_1/switch_f: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# conv5/bn/cond_1/pred_id: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2021-06-24 17:11:21.639862: I tensorflow/core/common_runtime/placer.cc:54] conv5/bn/cond_1/pred_id: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# conv5/bn/cond_1/Identity/Switch: (Switch): /job:localhost/replica:0/task:0/device:CPU:0
# ...
